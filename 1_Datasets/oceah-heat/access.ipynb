# %% [markdown]
# # Access Atlantic Ocean Heat Content
#
# [Explore Data](https://sunnydean.github.io/ocean_cubes_vis/?cube=https%3A%2F%2Fs3.waw4-1.cloudferro.com%2FEarthCODE%2FOSCAssets%2Fmed_cubes%2Focean-med-monthly-cube.zarr&variable=ohc)
#
#     * Original Data Source: https://www.aviso.altimetry.fr/en/data/products/ocean-indicators-products/ocean-heat-content-and-earth-energy-imbalance/atlantic-ocean-heat-content-change.html
#     * Reference:  https://www.aviso.altimetry.fr/fileadmin/documents/data/tools/OHC-EEI/OHCATL-DT-035-MAG_EDD_V3.0.pdf
#     * OSC entry: https://opensciencedata.esa.int/products/4d-atlantic-ohc-global/collection
#     * License: AVISO
#     * Cube Ready: YES

# %%
import xarray as xr

# %%
data_href = 'https://s3.waw4-1.cloudferro.com/EarthCODE/OSCAssets/ocean_datasets/ocean_heat.zarr/'

# %%
ds = xr.open_zarr(data_href, chunks={})
ds
# Out:
# <xarray.Dataset> Size: 385MB
# Dimensions:                     (latitude: 180, longitude: 360, time: 258,
#                                  time_covar: 22, time_covar_2: 22)
# Coordinates:
#   * latitude                    (latitude) float64 1kB -89.5 -88.5 ... 88.5 89.5
#   * longitude                   (longitude) float64 3kB -179.5 -178.5 ... 179.5
#   * time                        (time) object 2kB 2002-04-15 18:07:12.000001 ...
#   * time_covar                  (time_covar) object 176B 2002-07-02 00:00:00 ...
#   * time_covar_2                (time_covar_2) object 176B 2002-07-02 00:00:0...
# Data variables:
#     cell_surface                (latitude, longitude) float64 518kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     crs                         int64 8B ...
#     ohc                         (time, latitude, longitude) float64 134MB dask.array<chunksize=(100, 180, 360), meta=np.ndarray>
#     ohc_mask                    (time) float64 2kB dask.array<chunksize=(100,), meta=np.ndarray>
#     ohc_var_covar_matrix_local  (time_covar, time_covar_2, latitude, longitude) float64 251MB dask.array<chunksize=(22, 22, 180, 360), meta=np.ndarray>
# Attributes:
#     source:       satellite observation
#     history:      Creation: 2025-05-22
#     references:   https://doi.org/10.24400/527896/A01-2022.012
#     url:          https://www.aviso.altimetry.fr/en/data/products/ocean-indic...
#     Conventions:  CF-1.8
#     summary:      The OHC product results from the space geodetic approach al...
#     start_date:   2002-04-15
#     end_date:     2023-09-16
#     version:      3.0
#     comment:      See technical documentation ATBD and EDD, and peer-review a...
#     contact:      robin.fraudeau(at)magellium.fr

# %%
ds.ohc.isel(time=3).plot()
